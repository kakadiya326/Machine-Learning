# %%
from sklearn.preprocessing import OneHotEncoder
col=['Outlook','Temperature','Humidity','Wind']
import pandas as pd

df=pd.read_csv('./TennisData.csv')
oh=OneHotEncoder()
x=oh.fit_transform(df[col])
print(x)

# %%
oh.get_feature_names_out()
